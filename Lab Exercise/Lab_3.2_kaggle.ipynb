# %% [markdown]
# # Lab 3.2 Kaggle

# %% [markdown]
# created by ACZ 202402

# %%
# !pip install kaggle

# %% [markdown]
# ### open kaggle account > settings > create API token > upload kaggle.json

# %%
# !mkdir ~/.kaggle
# !mv kaggle.json ../.kaggle/
# !chmod 600 ../.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/home/ec2-user/.kaggle’: File exists
# mv: cannot stat ‘kaggle.json’: No such file or directory

# %% [markdown]
# if its not working, check kaggle.json directory and adjust <b>or</b> run !chmod only

# %% [markdown]
# ### open related dataset > upper-right corner > copy API command

# %%
# !kaggle datasets download -d heptapod/titanic
# Out:
# ...
#   0%|                                               | 0.00/10.8k [00:00<?, ?B/s]
# 100%|██████████████████████████████████████| 10.8k/10.8k [00:00<00:00, 30.5MB/s]

# %%
# !unzip titanic.zip
# Out:
# Archive:  titanic.zip
#   inflating: train_and_test2.csv

# %%
import pandas as pd
df = pd.read_csv("train_and_test2.csv") 
df.head(10)
# Out:
#    Passengerid   Age     Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0            1  22.0   7.2500    0      1     0       0       0       0
# 1            2  38.0  71.2833    1      1     0       0       0       0
# 2            3  26.0   7.9250    1      0     0       0       0       0
# 3            4  35.0  53.1000    1      1     0       0       0       0
# 4            5  35.0   8.0500    0      0     0       0       0       0
# 5            6  28.0   8.4583    0      0     0       0       0       0
# 6            7  54.0  51.8625    0      0     0       0       0       0
# 7            8   2.0  21.0750    0      3     0       0       0       0
# 8            9  27.0  11.1333    1      0     0       0       0       0
# 9           10  14.0  30.0708    1      1     0       0       0       0
#
#    zero.4  ...  zero.12  zero.13  zero.14  Pclass  zero.15  zero.16  Embarked  \
# 0       0  ...        0        0        0       3        0        0       2.0
# ...

# %%
df.shape
# Out:
# (1309, 28)

# %% [markdown]
# 1309 instances and 28 features/attributes
